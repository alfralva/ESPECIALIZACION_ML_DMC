# %% [markdown]
# <a href="https://colab.research.google.com/github/alfralva/ESPECIALIZACION_ML_DMC/blob/main/consumo_api_maxi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Start with an empty list
total_results = []

# Grab the search results
print("Downloading the original search results")
response = requests.get('https://analitix-gw-2c2ew472.ue.gateway.dev/api/v1/market-share?date=2024-01-01&page=15',headers={'Content-Type':'application/json','Authorization':'Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjY3YmFiYWFiYTEwNWFkZDZiM2ZiYjlmZjNmZjVmZTNkY2E0Y2VkYTEiLCJ0eXAiOiJKV1QifQ.....R_H7vnq5j2pqyUx8v7qumiuDCNlzWqIj3a7vx3BMHOfwqQwufjZRl43xWSc5lQaRLVPHEk3rn80LZfYFoS612gPTc79L7VDSwdMbHQ9sVLh93RF7mmTKoBGAWcstrxuwLSHZVQ31CiVO2YON0m5oerhkKXXkTLvTf2rhbYLeohEckmze7ApHkxvovJbdYKwGsvUkncJnU5VonikCWWR0KYtVJ4Geb4CCUKSiuwpMXJvGaduqy1JD_Bh5lOLYxFIU0WCXWgsVLTQD94zfjMCkrE0b_89s8okzWUXPoPsffSBWQAXjLs8o9I4c3T-X9pC8bkZ1DQ8eHJ7x10vIRTq4Mw'})
data = response.json()

data

# %%
response = requests.get('https://analitix-gw-2c2ew472.ue.gateway.dev/api/v1/market-share?date=2023-06-01&page=17',headers={'Content-Type':'application/json','Authorization':'Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjY3YmFiYWFiYTEwNWFkZDZiM2ZiYjlmZjNmZjVmZTNkY2E0Y2VkYTEiLCJ0eXAiOiJKV1QifQ.....R_H7vnq5j2pqyUx8v7qumiuDCNlzWqIj3a7vx3BMHOfwqQwufjZRl43xWSc5lQaRLVPHEk3rn80LZfYFoS612gPTc79L7VDSwdMbHQ9sVLh93RF7mmTKoBGAWcstrxuwLSHZVQ31CiVO2YON0m5oerhkKXXkTLvTf2rhbYLeohEckmze7ApHkxvovJbdYKwGsvUkncJnU5VonikCWWR0KYtVJ4Geb4CCUKSiuwpMXJvGaduqy1JD_Bh5lOLYxFIU0WCXWgsVLTQD94zfjMCkrE0b_89s8okzWUXPoPsffSBWQAXjLs8o9I4c3T-X9pC8bkZ1DQ8eHJ7x10vIRTq4Mw'})
data = response.json()

data
# Out:
# {'data': [{'providerName': '5523-LAS FRAGANCIAS CIA. LTDA.',
#    'providerCode': 5523,
#    'classCode': 4104,
#    'productClass': '4104-ACONDICIONADOR / RINSE',
#    'participation': 0.00010434847813040653,
#    'format': 'GRAN AKI',
#    'uopName': '357-GRAN AKI DURAN CENTRO',
#    'province': 'GUAYAS',
#    'barcode': 717226208898,
#    'date': '2023-06-01',
#    'subClass': '0060-ESPECIALIZADO',
#    'brandName': 'JOHN FRIEDA',
#    'itemName': '717226208898-JOHN FRIEDA AC.FRIZZ EASE MIRACULOUS RECOVERY'},
#   {'providerName': '5523-LAS FRAGANCIAS CIA. LTDA.',
#    'providerCode': 5523,
#    'classCode': 4104,
#    'productClass': '4104-ACONDICIONADOR / RINSE',
#    'participation': 0.00020869695626081307,
#    'format': 'SUPERMAXI',
#    'uopName': '125-SUPERMAXI SAN GABRIEL',
#    'province': 'PICHINCHA',
#    'barcode': 717226208898,
#    'date': '2023-06-01',
#    'subClass': '0060-ESPECIALIZADO',
#    'brandName': 'JOHN FRIEDA',
# ...

# %%
data

# %%
# Store the first page of results
total_results = total_results + data['data']

while data['brandName'] is not None:
    print("Next page found, downloading", data['brandName'])
    response = requests.get(data['brandName'])
    data = response.json()
    # Store the current page of results
    total_results = total_results + data['data']

print("We have", len(total_results), "total results")
